# %% [markdown]
# # Quiet Relay: 2026 — Notebook Runner
#
# This notebook runs the terminal combat core from `quiet_relay_terminal.py`.
#
# ## How to use
# 1. Run the setup cell.
# 2. Edit the configuration cell.
# 3. Run the battle cell.
# 4. Optionally inspect the saved battle log.
#
# ## Notes
# - Set `AUTO_MODE = True` for a full automated battle.
# - Set `AUTO_MODE = False` to use the script's manual prompts inside the notebook.
# - Valid party members: `vanguard`, `duelist`, `cantor`, `ranger`, `penitent`
# - Valid scenarios: `skirmish`, `elites`, `pack`, `bell_warden`, `flood_archivist`, `glass_hound_matriarch`, `quiet_magistrate`

# %%
from pathlib import Path
import importlib.util
import sys

SCRIPT_PATH = Path("/users/junhyeok/tbrg/quiet_relay_terminal.py")
DEFAULT_LOG_PATH = Path("users/junhyeok/tbrg/quiet_relay_last_battle_log.txt")

if not SCRIPT_PATH.exists():
    raise FileNotFoundError(f"Could not find: {SCRIPT_PATH}")

print(f"Using script: {SCRIPT_PATH}")
print(f"Default log path: {DEFAULT_LOG_PATH}")

def load_quiet_relay_module():
    module_name = "quiet_relay_terminal_nb"
    if module_name in sys.modules:
        del sys.modules[module_name]
    spec = importlib.util.spec_from_file_location(module_name, SCRIPT_PATH)
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    spec.loader.exec_module(module)
    return module

def run_quiet_relay(
    party="vanguard,duelist,cantor",
    scenario="bell_warden",
    auto_mode=True,
    seed=2026,
    log_file=DEFAULT_LOG_PATH,
):
    module = load_quiet_relay_module()
    argv = [
        "--party", party,
        "--scenario", scenario,
        "--seed", str(seed),
        "--log-file", str(log_file),
    ]
    if auto_mode:
        argv.append("--auto")

    print("Running with arguments:")
    print(" ".join(argv))
    print("-" * 72)
    rc = module.main(argv)
    print("-" * 72)
    print(f"Exit code: {rc}")
    return rc

def show_battle_log(log_file=DEFAULT_LOG_PATH):
    log_file = Path(log_file)
    if not log_file.exists():
        print(f"No log file found at: {log_file}")
        return
    print(log_file.read_text())
# Out:
# Using script: /users/junhyeok/tbrg/quiet_relay_terminal.py
# Default log path: users/junhyeok/tbrg/quiet_relay_last_battle_log.txt

# %%
# Edit these values, then run the battle cell below.

PARTY = "vanguard,duelist,cantor"
SCENARIO = "bell_warden"
AUTO_MODE = False
SEED = 2026
LOG_FILE = DEFAULT_LOG_PATH

print("Current configuration:")
print(" PARTY   =", PARTY)
print(" SCENARIO=", SCENARIO)
print(" AUTO    =", AUTO_MODE)
print(" SEED    =", SEED)
print(" LOG     =", LOG_FILE)
# Out:
# Current configuration:
#  PARTY   = vanguard,duelist,cantor
#  SCENARIO= bell_warden
#  AUTO    = False
#  SEED    = 2026
#  LOG     = users/junhyeok/tbrg/quiet_relay_last_battle_log.txt

# %%
# Run one battle
run_quiet_relay(
    party=PARTY,
    scenario=SCENARIO,
    auto_mode=AUTO_MODE,
    seed=SEED,
    log_file=LOG_FILE,
)
# Out:
# Running with arguments:
# --party vanguard,duelist,cantor --scenario bell_warden --seed 2026 --log-file users/junhyeok/tbrg/quiet_relay_last_battle_log.txt
# ------------------------------------------------------------------------
#
# Quiet Relay: 2026 - Terminal Combat Core
# ============================================================
# Party: vanguard, duelist, cantor
# Scenario: bell_warden
# Mode: INTERACTIVE
# ============================================================
# Tip: player actions require manual Power Precision Composure inputs such as: 72 61 84
# Enemy attacks will ask for Guard / Dodge / Parry reactions.
#
# Battle begins.
# Turn order: Duelist, Cantor, Bell Warden, Vanguard
#
# ====================================================================================
# ROUND 1 | Spotlight 0/5
# ------------------------------------------------------------------------------------
# PLAYERS
# >1. Vanguard           HP 160/160  GUARD  72/72   BREAK  90/90   ash    posture=flow
# >2. Duelist            HP 120/120  GUARD  46/46   BREAK  42/42   halo   posture=flow
# >3. Cantor             HP 120/120  GUARD  46/46   BREAK  64/64   shade  posture=flow
# ------------------------------------------------------------------------------------
# ENEMIES
# >1. Bell Warden        HP 430/430  GUARD 120/120  BREAK 130/130  ash    posture=flow
# ====================================================================================
#
#
# Duelist's turn. Choose a skill:
#   1. Standard Strike    [attack] cost=0 scale=power/precision target=single_enemy
#   2. Brace              [defense] cost=0 scale=composure/power target=self
#   3. Read Opening       [utility] cost=0 scale=precision/composure target=single_enemy
#   4. Mark Lunge         [attack] cost=0 scale=precision/power target=single_enemy
#   5. Feint Circuit      [stance] cost=0 scale=composure/precision target=self
# >  1
# Choose a target:
#   1. Bell Warden        HP 430/430  GUARD 120/120  BREAK 130/130  ash    posture=flow
# >  1
# Enter power precision composure [default 60 60 60] >  20 50 50
# Preview -> Power  20 (set), Precision  50 (keen), Composure  50 (keen) | Posture: flow (balanced spread)
# Press Enter to confirm or type r to re-enter >
# Duelist enters flow posture (balanced spread).
# Spotlight +1 (Duelist entered Flow) -> 1/5
# Duelist uses Standard Strike [P:20/set, R:50/keen, C:50/keen]
# Bell Warden loses 13 break.
# Duelist hits Bell Warden for 27 guard. CRIT!
# Spotlight +1 (Duelist passive crit) -> 2/5
#
# ====================================================================================
# ROUND 1 | Spotlight 2/5
# ------------------------------------------------------------------------------------
# PLAYERS
# >1. Vanguard           HP 160/160  GUARD  72/72   BREAK  90/90   ash    posture=flow
# >2. Duelist            HP 120/120  GUARD  46/46   BREAK  42/42   halo   posture=flow
# >3. Cantor             HP 120/120  GUARD  46/46   BREAK  64/64   shade  posture=flow
# ------------------------------------------------------------------------------------
# ENEMIES
# >1. Bell Warden        HP 430/430  GUARD  93/120  BREAK 117/130  ash    posture=flow
# ====================================================================================
#
#
# Cantor's turn. Choose a skill:
#   1. Standard Strike    [attack] cost=0 scale=power/precision target=single_enemy
#   2. Brace              [defense] cost=0 scale=composure/power target=self
#   3. Read Opening       [utility] cost=0 scale=precision/composure target=single_enemy
#   4. Salt Psalm         [spell] cost=0 scale=precision/composure target=single_enemy
#   5. Undertow Litany    [support] cost=1 scale=composure/precision target=all_allies
#   6. Hex Burst          [spell] cost=1 scale=precision/composure target=single_enemy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Run one battle
# ----> 2 run_quiet_relay(
#       3     party=PARTY,
#       4     scenario=SCENARIO,
#       5     auto_mode=AUTO_MODE,
#       6     seed=SEED,
#       7     log_file=LOG_FILE,
#       8 )
#
# Cell In[1], line 44, in run_quiet_relay(party, scenario, auto_mode, seed, log_file)
#      42 print(" ".join(argv))
#      43 print("-" * 72)
# ---> 44 rc = module.main(argv)
#      45 print("-" * 72)
#      46 print(f"Exit code: {rc}")
#
# File /users/junhyeok/tbrg/quiet_relay_terminal.py:2471, in main(argv)
#    2462 state = BattleState(
#    2463     players=players,
#    2464     enemies=enemies,
#    (...)   2467     interactive=not args.auto,
#    2468 )
#    2470 print_intro(args, party_ids)
# -> 2471 winner = run_battle(state)
#    2472 state.save_log(args.log_file)
#    2473 print(f"\nBattle log written to: {args.log_file}")
#
# File /users/junhyeok/tbrg/quiet_relay_terminal.py:2339, in run_battle(state)
#    2337 if state.check_end():
#    2338     break
# -> 2339 process_turn(state, actor)
#    2340 if state.check_end():
#    2341     break
#
# File /users/junhyeok/tbrg/quiet_relay_terminal.py:2322, in process_turn(state, actor)
#    2319     state.logger.log(state.round_number, f"{actor.name} recovers {recovered} guard.")
#    2321 if actor.team == "player":
# -> 2322     perform_player_action(state, actor)
#    2323 else:
#    2324     enemy_action_template(state, actor)
#
# File /users/junhyeok/tbrg/quiet_relay_terminal.py:1572, in perform_player_action(state, actor)
#    1570 if state.interactive:
#    1571     state.render_state()
# -> 1572     skill = choose_player_skill(state, actor)
#    1573     targets = choose_target(state, actor, skill)
#    1574     resolved_inputs = prompt_triplet(state.last_player_inputs, skill)
#
# File /users/junhyeok/tbrg/quiet_relay_terminal.py:1480, in choose_player_skill(state, actor)
#    1473 for idx, skill in enumerate(available, start=1):
#    1474     print(
#    1475         f"  {idx}. {skill.display_name:<18} "
#    1476         f"[{skill.kind}] cost={skill.spotlight_cost} "
#    1477         f"scale={skill.primary_scale}/{skill.secondary_scale} "
#    1478         f"target={skill.target}"
#    1479     )
# -> 1480 raw = input("> ").strip()
#    1481 if raw == "" and available:
#    1482     return available[0]
#
# File /venv/main/lib/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File /venv/main/lib/python3.12/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Inspect the saved log
show_battle_log(LOG_FILE)

# %% [markdown]
# ## Quick presets
#
# Try any of these by changing the configuration cell:
#
# ```python
# PARTY = "vanguard,duelist,cantor"
# SCENARIO = "bell_warden"
# AUTO_MODE = True
# ```
#
# ```python
# PARTY = "ranger,penitent,cantor"
# SCENARIO = "skirmish"
# AUTO_MODE = True
# ```
#
# ```python
# PARTY = "vanguard,duelist,cantor"
# SCENARIO = "quiet_magistrate"
# AUTO_MODE = False
# ```
